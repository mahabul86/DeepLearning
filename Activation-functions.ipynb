# %%
import numpy as np #Metrix calculation #Number analysis
import matplotlib.pyplot as plt #Visualisation
# %matplotlib inline

# %%
x = np.arange(-5, 5, 0.01)

# %%
def plot(func, yaxis = (-1.4, 1.4)):
    plt.ylim(yaxis)
    plt.locator_params(nbins = 5)
    plt.xticks(fontsize = 15)
    plt.yticks(fontsize = 15)
    plt.axhline(lw = 1, c = 'black')
    plt.axvline(lw = 1, c = 'black')
    plt.grid(alpha = 0.3, ls = '-.')
    plt.box(on = None)
    plt.plot(x, func(x), c = 'b', lw = 3) # Recursion = Repeated

# %%
binary_step = np.vectorize(lambda x: 1 if x > 0 else 0, otypes = [np.float64])

# %%
plot(binary_step, yaxis = (-0.4, 1.4)) #constructor

# %%
piecewise_linear = np.vectorize(lambda x: 1 if x >3 else 0 if x<3 else 2)

# %%
plot(piecewise_linear)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
plot(sigmoid)

# %%
relu = np.vectorize(lambda x: x if x>0 else 0, otypes = [np.float64])

# %%
plot(relu)

# %%
leaky_relu = np.vectorize(lambda x: x if max(0.1 *x, x) else 0, otypes = [np.float64])

# %%
plot(leaky_relu)

# %%
# Exponential Linear Units [ELU]
elu = np.vectorize(lambda x: x if x > 0 else 0.5* (np.exp(x) - 1), otypes = [np.float64])

# %%
plot(elu)

# %%
def softplus(x):
    return np.log(1+ np.exp(x))

# %%
plot(softplus)
